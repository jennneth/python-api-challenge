# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
import requests
import time
import datetime
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

#Incorporates ratelimit to prevent exceeding API call limit
#I ended up not using this
#from ratelimit import limits, sleep_and_retry

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
#lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
#lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)


#let's start with a smaller list of cities 
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)

lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
#print(cities)
# Out:
# 611

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"

#initialize the lists
cloudiness = []
country = []
date = []
humidity = []
longitude = []
latitude = []
max_temp = []
wind_speed = []
city_name = []
city_id = []

# %%
record_counter = 0
set_counter = 0
units = "imperial"

for city in cities:
    # Build query URL 
    query_url = f"{url}appid={weather_api_key}&q={city}&units={units}"
    #for every 50 cities processed, increment the set counter and pause for 90 seconds
    if cities.index(city)%50==0:
        time.sleep(90)
        set_counter += 1
        record_counter = 0
    else:
        record_counter +=1
    
    print(f"Processing record {record_counter} of set {set_counter} | {city}") 
    
    weather_json = requests.get(query_url).json()
    try:  
        longitude.append(weather_json["coord"]["lon"])
        latitude.append(weather_json["coord"]["lat"])
        max_temp.append(weather_json["main"]["temp_max"])
        cloudiness.append(weather_json["clouds"]["all"])
        country.append(weather_json["sys"]["country"])
        date.append(weather_json["dt"])
        humidity.append(weather_json["main"]["humidity"])
        wind_speed.append(weather_json["wind"]["speed"])
        city_name.append(city)
        city_id.append(weather_json["id"])
    except:
        print(f"City {city} not found. Continuing...")
# Out:
# Processing record 0 of set 1 | talkha
# Processing record 1 of set 1 | ushuaia
# Processing record 2 of set 1 | grindavik
# Processing record 3 of set 1 | odienne
# Processing record 4 of set 1 | matagami
# Processing record 5 of set 1 | omaruru
# Processing record 6 of set 1 | tawang
# Processing record 7 of set 1 | illoqqortoormiut
# City illoqqortoormiut not found. Continuing...
# Processing record 8 of set 1 | ovsyanka
# Processing record 9 of set 1 | bredasdorp
# Processing record 10 of set 1 | masuguru
# Processing record 11 of set 1 | ramanuj ganj
# Processing record 12 of set 1 | bluff
# Processing record 13 of set 1 | busselton
# Processing record 14 of set 1 | puerto ayora
# Processing record 15 of set 1 | flinders
# Processing record 16 of set 1 | paamiut
# Processing record 17 of set 1 | santa isabel do rio negro
# Processing record 18 of set 1 | mys shmidta
# City mys shmidta not found. Continuing...
# Processing record 19 of set 1 | kapaa
# Processing record 20 of set 1 | provideniya
# Processing record 21 of set 1 | znamenskoye
# Processing record 22 of set 1 | beloha
# Processing record 23 of set 1 | taolanaro
# City taolanaro not found. Continuing...
# Processing record 24 of set 1 | victoria
# Processing record 25 of set 1 | airai
# Processing record 26 of set 1 | cape town
# Processing record 27 of set 1 | amderma
# City amderma not found. Continuing...
# Processing record 28 of set 1 | hilo
# Processing record 29 of set 1 | hithadhoo
# Processing record 30 of set 1 | barentsburg
# City barentsburg not found. Continuing...
# Processing record 31 of set 1 | cutervo
# Processing record 32 of set 1 | clyde river
# Processing record 33 of set 1 | sao jose de piranhas
# Processing record 34 of set 1 | barrow
# Processing record 35 of set 1 | portland
# Processing record 36 of set 1 | umzimvubu
# City umzimvubu not found. Continuing...
# Processing record 37 of set 1 | vizinga
# Processing record 38 of set 1 | touros
# Processing record 39 of set 1 | shingu
# Processing record 40 of set 1 | punta arenas
# Processing record 41 of set 1 | ituporanga
# Processing record 42 of set 1 | saleaula
# City saleaula not found. Continuing...
# Processing record 43 of set 1 | pisco
# Processing record 44 of set 1 | yulara
# Processing record 45 of set 1 | panjwin
# City panjwin not found. Continuing...
# Processing record 46 of set 1 | laguna
# Processing record 47 of set 1 | rikitea
# Processing record 48 of set 1 | hammerfest
# Processing record 49 of set 1 | avarua
# Processing record 0 of set 2 | kokopo
# Processing record 1 of set 2 | acapulco
# Processing record 2 of set 2 | tsihombe
# City tsihombe not found. Continuing...
# Processing record 3 of set 2 | ribeira grande
# Processing record 4 of set 2 | thompson
# Processing record 5 of set 2 | cayenne
# Processing record 6 of set 2 | risaralda
# Processing record 7 of set 2 | albany
# Processing record 8 of set 2 | lavrentiya
# Processing record 9 of set 2 | mailsi
# Processing record 10 of set 2 | chumikan
# Processing record 11 of set 2 | jamestown
# Processing record 12 of set 2 | goure
# Processing record 13 of set 2 | new norfolk
# Processing record 14 of set 2 | cockburn town
# Processing record 15 of set 2 | arraial do cabo
# Processing record 16 of set 2 | medea
# Processing record 17 of set 2 | broome
# Processing record 18 of set 2 | horta
# Processing record 19 of set 2 | verkhovazhye
# Processing record 20 of set 2 | kahului
# Processing record 21 of set 2 | storforshei
# Processing record 22 of set 2 | salym
# Processing record 23 of set 2 | dikson
# Processing record 24 of set 2 | bontang
# Processing record 25 of set 2 | attawapiskat
# City attawapiskat not found. Continuing...
# Processing record 26 of set 2 | lompoc
# Processing record 27 of set 2 | butaritari
# Processing record 28 of set 2 | nawada
# Processing record 29 of set 2 | sakhon nakhon
# Processing record 30 of set 2 | gwalior
# Processing record 31 of set 2 | port alfred
# Processing record 32 of set 2 | seoul
# Processing record 33 of set 2 | bengkulu
# Processing record 34 of set 2 | vardo
# Processing record 35 of set 2 | luderitz
# Processing record 36 of set 2 | vihti
# Processing record 37 of set 2 | linjiang
# Processing record 38 of set 2 | ancud
# Processing record 39 of set 2 | mahibadhoo
# Processing record 40 of set 2 | tumannyy
# City tumannyy not found. Continuing...
# Processing record 41 of set 2 | barao de melgaco
# Processing record 42 of set 2 | bethel
# Processing record 43 of set 2 | demba
# Processing record 44 of set 2 | dolbeau
# City dolbeau not found. Continuing...
# Processing record 45 of set 2 | parabel
# Processing record 46 of set 2 | eatonton
# Processing record 47 of set 2 | eldikan
# City eldikan not found. Continuing...
# Processing record 48 of set 2 | toliary
# City toliary not found. Continuing...
# Processing record 49 of set 2 | nishihara
# Processing record 0 of set 3 | hermanus
# Processing record 1 of set 3 | san quintin
# Processing record 2 of set 3 | vanimo
# Processing record 3 of set 3 | lodja
# Processing record 4 of set 3 | mataura
# Processing record 5 of set 3 | samarai
# Processing record 6 of set 3 | nizhneyansk
# City nizhneyansk not found. Continuing...
# Processing record 7 of set 3 | caravelas
# Processing record 8 of set 3 | georgetown
# Processing record 9 of set 3 | bilma
# Processing record 10 of set 3 | stawell
# Processing record 11 of set 3 | hinton
# Processing record 12 of set 3 | puerto suarez
# Processing record 13 of set 3 | bethlehem
# Processing record 14 of set 3 | aklavik
# Processing record 15 of set 3 | kuching
# Processing record 16 of set 3 | cape canaveral
# Processing record 17 of set 3 | sahrak
# City sahrak not found. Continuing...
# Processing record 18 of set 3 | urubicha
# Processing record 19 of set 3 | severo-kurilsk
# Processing record 20 of set 3 | tidore
# City tidore not found. Continuing...
# Processing record 21 of set 3 | vaini
# Processing record 22 of set 3 | longyearbyen
# Processing record 23 of set 3 | dalinghe
# City dalinghe not found. Continuing...
# Processing record 24 of set 3 | clarence town
# Processing record 25 of set 3 | shenjiamen
# Processing record 26 of set 3 | saskylakh
# Processing record 27 of set 3 | hobart
# Processing record 28 of set 3 | kouroussa
# Processing record 29 of set 3 | chapais
# Processing record 30 of set 3 | tucuman
# Processing record 31 of set 3 | saint-philippe
# Processing record 32 of set 3 | coolum beach
# Processing record 33 of set 3 | carnarvon
# Processing record 34 of set 3 | eyl
# Processing record 35 of set 3 | upernavik
# Processing record 36 of set 3 | asyut
# Processing record 37 of set 3 | douglas
# Processing record 38 of set 3 | padang
# Processing record 39 of set 3 | alofi
# Processing record 40 of set 3 | primo tapia
# Processing record 41 of set 3 | torbay
# Processing record 42 of set 3 | indianola
# Processing record 43 of set 3 | pasni
# Processing record 44 of set 3 | natal
# Processing record 45 of set 3 | tuatapere
# Processing record 46 of set 3 | guarapari
# Processing record 47 of set 3 | praia da vitoria
# Processing record 48 of set 3 | mahebourg
# Processing record 49 of set 3 | alugan
# Processing record 0 of set 4 | fortuna
# Processing record 1 of set 4 | bandarbeyla
# Processing record 2 of set 4 | churapcha
# Processing record 3 of set 4 | brewster
# Processing record 4 of set 4 | qaanaaq
# Processing record 5 of set 4 | dunedin
# Processing record 6 of set 4 | belaya gora
# Processing record 7 of set 4 | khorramabad
# Processing record 8 of set 4 | coihaique
# Processing record 9 of set 4 | leningradskiy
# Processing record 10 of set 4 | kaeo
# Processing record 11 of set 4 | havre-saint-pierre
# Processing record 12 of set 4 | hospet
# Processing record 13 of set 4 | hualmay
# Processing record 14 of set 4 | henties bay
# Processing record 15 of set 4 | atuona
# Processing record 16 of set 4 | andros town
# Processing record 17 of set 4 | gamba
# Processing record 18 of set 4 | iqaluit
# Processing record 19 of set 4 | krasnopillya
# Processing record 20 of set 4 | berlevag
# Processing record 21 of set 4 | yamada
# Processing record 22 of set 4 | wanning
# Processing record 23 of set 4 | hamilton
# Processing record 24 of set 4 | salinopolis
# Processing record 25 of set 4 | baikunthpur
# Processing record 26 of set 4 | sebastian
# Processing record 27 of set 4 | havoysund
# Processing record 28 of set 4 | trunovskoye
# Processing record 29 of set 4 | east london
# Processing record 30 of set 4 | tuktoyaktuk
# Processing record 31 of set 4 | bur gabo
# City bur gabo not found. Continuing...
# Processing record 32 of set 4 | vilhena
# Processing record 33 of set 4 | belushya guba
# City belushya guba not found. Continuing...
# Processing record 34 of set 4 | surazh
# Processing record 35 of set 4 | cherskiy
# Processing record 36 of set 4 | eganville
# Processing record 37 of set 4 | isangel
# Processing record 38 of set 4 | pangnirtung
# Processing record 39 of set 4 | kavieng
# Processing record 40 of set 4 | port elizabeth
# Processing record 41 of set 4 | meyungs
# City meyungs not found. Continuing...
# Processing record 42 of set 4 | barrhead
# Processing record 43 of set 4 | tillabery
# City tillabery not found. Continuing...
# Processing record 44 of set 4 | yellowknife
# Processing record 45 of set 4 | bolshoye nagatkino
# Processing record 46 of set 4 | poum
# Processing record 47 of set 4 | sambava
# Processing record 48 of set 4 | kamenka
# Processing record 49 of set 4 | hasaki
# Processing record 0 of set 5 | zaozerne
# Processing record 1 of set 5 | jodhpur
# Processing record 2 of set 5 | castro
# Processing record 3 of set 5 | cowra
# Processing record 4 of set 5 | pescara
# Processing record 5 of set 5 | qaqortoq
# Processing record 6 of set 5 | sisimiut
# Processing record 7 of set 5 | geraldton
# Processing record 8 of set 5 | nanortalik
# Processing record 9 of set 5 | yar-sale
# Processing record 10 of set 5 | nikolskoye
# Processing record 11 of set 5 | marsa matruh
# Processing record 12 of set 5 | ostrovnoy
# Processing record 13 of set 5 | jinchang
# Processing record 14 of set 5 | papara
# Processing record 15 of set 5 | salalah
# Processing record 16 of set 5 | guerrero negro
# Processing record 17 of set 5 | tiznit
# Processing record 18 of set 5 | chuy
# Processing record 19 of set 5 | shaki
# Processing record 20 of set 5 | port moresby
# Processing record 21 of set 5 | grand river south east
# City grand river south east not found. Continuing...
# Processing record 22 of set 5 | dauriya
# Processing record 23 of set 5 | jardim
# Processing record 24 of set 5 | antequera
# Processing record 25 of set 5 | marcona
# City marcona not found. Continuing...
# Processing record 26 of set 5 | tasiilaq
# Processing record 27 of set 5 | boa vista
# Processing record 28 of set 5 | marsabit
# Processing record 29 of set 5 | ust-kan
# Processing record 30 of set 5 | baoshan
# Processing record 31 of set 5 | san policarpo
# Processing record 32 of set 5 | riyadh
# Processing record 33 of set 5 | ponta do sol
# Processing record 34 of set 5 | jinan
# Processing record 35 of set 5 | vila velha
# Processing record 36 of set 5 | simbahan
# Processing record 37 of set 5 | fevralsk
# City fevralsk not found. Continuing...
# Processing record 38 of set 5 | anshun
# Processing record 39 of set 5 | lorengau
# Processing record 40 of set 5 | mar del plata
# Processing record 41 of set 5 | vallenar
# Processing record 42 of set 5 | abha
# Processing record 43 of set 5 | nosy varika
# Processing record 44 of set 5 | san patricio
# Processing record 45 of set 5 | codrington
# Processing record 46 of set 5 | booue
# Processing record 47 of set 5 | lazaro cardenas
# Processing record 48 of set 5 | kawalu
# Processing record 49 of set 5 | svetlogorsk
# Processing record 0 of set 6 | zheleznodorozhnyy
# Processing record 1 of set 6 | lyudinovo
# Processing record 2 of set 6 | khatanga
# Processing record 3 of set 6 | batagay-alyta
# Processing record 4 of set 6 | cabo san lucas
# Processing record 5 of set 6 | ilulissat
# Processing record 6 of set 6 | aswan
# Processing record 7 of set 6 | san andres
# Processing record 8 of set 6 | tacoronte
# Processing record 9 of set 6 | catamarca
# Processing record 10 of set 6 | kangavar
# Processing record 11 of set 6 | black river
# Processing record 12 of set 6 | port hardy
# Processing record 13 of set 6 | pulau sebang
# Processing record 14 of set 6 | ulaangom
# Processing record 15 of set 6 | juneau
# Processing record 16 of set 6 | lebu
# Processing record 17 of set 6 | diffa
# Processing record 18 of set 6 | beringovskiy
# Processing record 19 of set 6 | sitka
# Processing record 20 of set 6 | trairi
# Processing record 21 of set 6 | soubre
# Processing record 22 of set 6 | rubtsovsk
# Processing record 23 of set 6 | brae
# Processing record 24 of set 6 | ugoofaaru
# Processing record 25 of set 6 | kirillov
# Processing record 26 of set 6 | miraflores
# Processing record 27 of set 6 | esperance
# Processing record 28 of set 6 | namatanai
# Processing record 29 of set 6 | dahuk
# Processing record 30 of set 6 | port augusta
# Processing record 31 of set 6 | fairbanks
# Processing record 32 of set 6 | solovetskiy
# City solovetskiy not found. Continuing...
# Processing record 33 of set 6 | avera
# Processing record 34 of set 6 | kollam
# Processing record 35 of set 6 | marsh harbour
# Processing record 36 of set 6 | norman wells
# Processing record 37 of set 6 | pinsk
# Processing record 38 of set 6 | sogne
# Processing record 39 of set 6 | cidreira
# Processing record 40 of set 6 | kankan
# Processing record 41 of set 6 | bulaevo
# Processing record 42 of set 6 | ust-kamchatsk
# City ust-kamchatsk not found. Continuing...
# Processing record 43 of set 6 | nadvoitsy
# Processing record 44 of set 6 | solok
# Processing record 45 of set 6 | umm kaddadah
# Processing record 46 of set 6 | soteapan
# Processing record 47 of set 6 | ewa beach
# Processing record 48 of set 6 | faanui
# Processing record 49 of set 6 | point pleasant
# Processing record 0 of set 7 | asfi
# Processing record 1 of set 7 | chicama
# Processing record 2 of set 7 | atar
# Processing record 3 of set 7 | atherton
# Processing record 4 of set 7 | lolua
# City lolua not found. Continuing...
# Processing record 5 of set 7 | merauke
# Processing record 6 of set 7 | chipata
# Processing record 7 of set 7 | qui nhon
# Processing record 8 of set 7 | malanje
# Processing record 9 of set 7 | aripuana
# Processing record 10 of set 7 | te anau
# Processing record 11 of set 7 | umm durman
# City umm durman not found. Continuing...
# Processing record 12 of set 7 | necochea
# Processing record 13 of set 7 | kodiak
# Processing record 14 of set 7 | harper
# Processing record 15 of set 7 | katsuura
# Processing record 16 of set 7 | saint george
# Processing record 17 of set 7 | karaton
# Processing record 18 of set 7 | narsaq
# Processing record 19 of set 7 | gat
# Processing record 20 of set 7 | faya
# Processing record 21 of set 7 | hofn
# Processing record 22 of set 7 | ondjiva
# Processing record 23 of set 7 | bronnoysund
# Processing record 24 of set 7 | santa barbara
# Processing record 25 of set 7 | dali
# Processing record 26 of set 7 | qasigiannguit
# Processing record 27 of set 7 | cabedelo
# Processing record 28 of set 7 | temba
# Processing record 29 of set 7 | kruisfontein
# Processing record 30 of set 7 | chokurdakh
# Processing record 31 of set 7 | takanosu
# Processing record 32 of set 7 | hay river
# Processing record 33 of set 7 | bharatpur
# Processing record 34 of set 7 | cururupu
# Processing record 35 of set 7 | dubbo
# Processing record 36 of set 7 | tubigan
# Processing record 37 of set 7 | saint-georges
# Processing record 38 of set 7 | carbonear
# Processing record 39 of set 7 | ngunguru
# Processing record 40 of set 7 | olafsvik
# Processing record 41 of set 7 | dingle
# Processing record 42 of set 7 | maragogi
# Processing record 43 of set 7 | shelburne
# Processing record 44 of set 7 | kulachi
# Processing record 45 of set 7 | tevaitoa
# Processing record 46 of set 7 | jijiga
# Processing record 47 of set 7 | bjornevatn
# Processing record 48 of set 7 | aracati
# Processing record 49 of set 7 | chaiya
# Processing record 0 of set 8 | los llanos de aridane
# Processing record 1 of set 8 | korla
# Processing record 2 of set 8 | savannah bight
# Processing record 3 of set 8 | esmeraldas
# Processing record 4 of set 8 | talnakh
# Processing record 5 of set 8 | samusu
# City samusu not found. Continuing...
# Processing record 6 of set 8 | nevsehir
# Processing record 7 of set 8 | tocache
# Processing record 8 of set 8 | bereda
# Processing record 9 of set 8 | rungata
# City rungata not found. Continuing...
# Processing record 10 of set 8 | port lincoln
# Processing record 11 of set 8 | pevek
# Processing record 12 of set 8 | rio gallegos
# Processing record 13 of set 8 | timra
# Processing record 14 of set 8 | bolungarvik
# City bolungarvik not found. Continuing...
# Processing record 15 of set 8 | gangotri
# City gangotri not found. Continuing...
# Processing record 16 of set 8 | ahipara
# Processing record 17 of set 8 | hambantota
# Processing record 18 of set 8 | san matias
# Processing record 19 of set 8 | tunduru
# City tunduru not found. Continuing...
# Processing record 20 of set 8 | gurupi
# Processing record 21 of set 8 | acarau
# Processing record 22 of set 8 | buala
# Processing record 23 of set 8 | tommot
# Processing record 24 of set 8 | ryotsu
# Processing record 25 of set 8 | paragominas
# Processing record 26 of set 8 | aksarka
# Processing record 27 of set 8 | kaitangata
# Processing record 28 of set 8 | xiongshi
# City xiongshi not found. Continuing...
# Processing record 29 of set 8 | novyy urengoy
# Processing record 30 of set 8 | tiarei
# Processing record 31 of set 8 | floresta
# Processing record 32 of set 8 | northam
# Processing record 33 of set 8 | hervey bay
# Processing record 34 of set 8 | marsala
# Processing record 35 of set 8 | prieska
# Processing record 36 of set 8 | sorland
# Processing record 37 of set 8 | bonfim
# Processing record 38 of set 8 | mildura
# Processing record 39 of set 8 | zemaiciu naumiestis
# Processing record 40 of set 8 | mitsamiouli
# Processing record 41 of set 8 | marigot
# Processing record 42 of set 8 | stephenville
# Processing record 43 of set 8 | mehamn
# Processing record 44 of set 8 | saldanha
# Processing record 45 of set 8 | russell
# Processing record 46 of set 8 | montes altos
# Processing record 47 of set 8 | rudbar
# Processing record 48 of set 8 | nemuro
# Processing record 49 of set 8 | maua
# Processing record 0 of set 9 | vaitupu
# City vaitupu not found. Continuing...
# Processing record 1 of set 9 | luanda
# Processing record 2 of set 9 | bambous virieux
# Processing record 3 of set 9 | benguela
# Processing record 4 of set 9 | gatesville
# Processing record 5 of set 9 | general roca
# Processing record 6 of set 9 | klaksvik
# Processing record 7 of set 9 | zhaoqing
# Processing record 8 of set 9 | helena
# Processing record 9 of set 9 | pathalgaon
# Processing record 10 of set 9 | college
# Processing record 11 of set 9 | masyaf
# Processing record 12 of set 9 | olinda
# Processing record 13 of set 9 | ibb
# Processing record 14 of set 9 | chapeltown
# Processing record 15 of set 9 | amahai
# Processing record 16 of set 9 | palabuhanratu
# City palabuhanratu not found. Continuing...
# Processing record 17 of set 9 | suluq
# Processing record 18 of set 9 | srednekolymsk
# Processing record 19 of set 9 | zheshart
# Processing record 20 of set 9 | bull savanna
# Processing record 21 of set 9 | cotonou
# Processing record 22 of set 9 | totskoye
# Processing record 23 of set 9 | sokoni
# Processing record 24 of set 9 | atasu
# Processing record 25 of set 9 | zhangye
# Processing record 26 of set 9 | mecca
# Processing record 27 of set 9 | elizabeth city
# Processing record 28 of set 9 | wilmington
# Processing record 29 of set 9 | tabiauea
# City tabiauea not found. Continuing...
# Processing record 30 of set 9 | alhaurin el grande
# Processing record 31 of set 9 | tarakan
# Processing record 32 of set 9 | deputatskiy
# Processing record 33 of set 9 | kirakira
# Processing record 34 of set 9 | lesnoy
# Processing record 35 of set 9 | horizontina
# Processing record 36 of set 9 | ust-ilimsk
# Processing record 37 of set 9 | teguldet
# Processing record 38 of set 9 | pallipattu
# Processing record 39 of set 9 | belyy yar
# Processing record 40 of set 9 | buraydah
# Processing record 41 of set 9 | gulshat
# City gulshat not found. Continuing...
# Processing record 42 of set 9 | shetpe
# Processing record 43 of set 9 | pochutla
# Processing record 44 of set 9 | sentyabrskiy
# City sentyabrskiy not found. Continuing...
# Processing record 45 of set 9 | hanstholm
# Processing record 46 of set 9 | buritica
# Processing record 47 of set 9 | krosno odrzanskie
# Processing record 48 of set 9 | cozumel
# Processing record 49 of set 9 | sobolevo
# Processing record 0 of set 10 | labuhan
# Processing record 1 of set 10 | mandalgovi
# Processing record 2 of set 10 | argelia
# Processing record 3 of set 10 | palu
# Processing record 4 of set 10 | slave lake
# Processing record 5 of set 10 | bafq
# Processing record 6 of set 10 | nyurba
# Processing record 7 of set 10 | teahupoo
# Processing record 8 of set 10 | kenai
# Processing record 9 of set 10 | japura
# Processing record 10 of set 10 | roma
# Processing record 11 of set 10 | biak
# Processing record 12 of set 10 | port macquarie
# Processing record 13 of set 10 | el doncello
# Processing record 14 of set 10 | rawson
# Processing record 15 of set 10 | temaraia
# City temaraia not found. Continuing...
# Processing record 16 of set 10 | sangar
# Processing record 17 of set 10 | neuquen
# Processing record 18 of set 10 | misratah
# Processing record 19 of set 10 | la rochelle
# Processing record 20 of set 10 | traiguen
# Processing record 21 of set 10 | castanos
# Processing record 22 of set 10 | cap malheureux
# Processing record 23 of set 10 | bathsheba
# Processing record 24 of set 10 | kabalo
# Processing record 25 of set 10 | saint-augustin
# Processing record 26 of set 10 | akureyri
# Processing record 27 of set 10 | richards bay
# Processing record 28 of set 10 | nelson bay
# Processing record 29 of set 10 | san cristobal
# Processing record 30 of set 10 | santa maria
# Processing record 31 of set 10 | tadine
# Processing record 32 of set 10 | okha
# Processing record 33 of set 10 | gombong
# Processing record 34 of set 10 | rio grande
# Processing record 35 of set 10 | peruibe
# Processing record 36 of set 10 | kibakwe
# Processing record 37 of set 10 | kaoma
# Processing record 38 of set 10 | derzhavinsk
# Processing record 39 of set 10 | ambulu
# Processing record 40 of set 10 | sterling
# Processing record 41 of set 10 | itacoatiara
# Processing record 42 of set 10 | hovd
# Processing record 43 of set 10 | longlac
# City longlac not found. Continuing...
# Processing record 44 of set 10 | bonavista
# Processing record 45 of set 10 | vao
# Processing record 46 of set 10 | qostanay
# Processing record 47 of set 10 | mareeba
# Processing record 48 of set 10 | kodinsk
# Processing record 49 of set 10 | saryshagan
# City saryshagan not found. Continuing...
# Processing record 0 of set 11 | mormugao
# Processing record 1 of set 11 | liaozhong
# Processing record 2 of set 11 | kununurra
# Processing record 3 of set 11 | oktyabrskoye
# Processing record 4 of set 11 | yanchukan
# City yanchukan not found. Continuing...
# Processing record 5 of set 11 | bilibino
# Processing record 6 of set 11 | evensk
# Processing record 7 of set 11 | tuchola
# Processing record 8 of set 11 | puerto escondido
# Processing record 9 of set 11 | okhansk
# Processing record 10 of set 11 | menongue
# Processing record 11 of set 11 | zyryanka
# Processing record 12 of set 11 | udachnyy
# Processing record 13 of set 11 | awbari
# Processing record 14 of set 11 | taltal
# Processing record 15 of set 11 | marienburg
# Processing record 16 of set 11 | elko
# Processing record 17 of set 11 | banda aceh
# Processing record 18 of set 11 | kloulklubed
# Processing record 19 of set 11 | pontes e lacerda
# Processing record 20 of set 11 | taoudenni
# Processing record 21 of set 11 | bantou
# Processing record 22 of set 11 | naryan-mar
# Processing record 23 of set 11 | mayo
# Processing record 24 of set 11 | maceio
# Processing record 25 of set 11 | bullhead city
# Processing record 26 of set 11 | pacific grove
# Processing record 27 of set 11 | sur
# Processing record 28 of set 11 | bay roberts
# Processing record 29 of set 11 | tarrega
# Processing record 30 of set 11 | haines junction
# Processing record 31 of set 11 | moundou
# Processing record 32 of set 11 | greenfield
# Processing record 33 of set 11 | kara-tyube
# Processing record 34 of set 11 | baruun-urt
# Processing record 35 of set 11 | kutum
# Processing record 36 of set 11 | erzincan
# Processing record 37 of set 11 | peleduy
# Processing record 38 of set 11 | berdigestyakh
# Processing record 39 of set 11 | tabas
# Processing record 40 of set 11 | uravakonda
# Processing record 41 of set 11 | souillac
# Processing record 42 of set 11 | manokwari
# Processing record 43 of set 11 | erzin
# Processing record 44 of set 11 | hami
# Processing record 45 of set 11 | gebre guracha
# Processing record 46 of set 11 | santiago de cao
# Processing record 47 of set 11 | petropavlovsk-kamchatskiy
# Processing record 48 of set 11 | de-kastri
# Processing record 49 of set 11 | tateyama
# Processing record 0 of set 12 | bokspits
# City bokspits not found. Continuing...
# Processing record 1 of set 12 | san javier
# Processing record 2 of set 12 | ust-omchug
# Processing record 3 of set 12 | viedma
# Processing record 4 of set 12 | porbandar
# Processing record 5 of set 12 | hobyo
# Processing record 6 of set 12 | sioux lookout
# Processing record 7 of set 12 | jian
# Processing record 8 of set 12 | phan thiet
# Processing record 9 of set 12 | quatre cocos
# Processing record 10 of set 12 | huilong
# Processing record 11 of set 12 | gravdal
# Processing record 12 of set 12 | meybod
# Processing record 13 of set 12 | meadow lake
# Processing record 14 of set 12 | sao pedro da aldeia
# Processing record 15 of set 12 | karratha
# Processing record 16 of set 12 | inhambane
# Processing record 17 of set 12 | praya
# Processing record 18 of set 12 | wonthaggi
# Processing record 19 of set 12 | roald
# Processing record 20 of set 12 | oksfjord
# Processing record 21 of set 12 | rangapara
# Processing record 22 of set 12 | xapuri
# Processing record 23 of set 12 | nioro
# Processing record 24 of set 12 | francavilla al mare
# Processing record 25 of set 12 | erenhot
# Processing record 26 of set 12 | oktyabrskiy
# Processing record 27 of set 12 | viligili
# City viligili not found. Continuing...
# Processing record 28 of set 12 | atoyac
# Processing record 29 of set 12 | esna
# Processing record 30 of set 12 | tessalit
# Processing record 31 of set 12 | bossier city
# Processing record 32 of set 12 | vestmanna
# Processing record 33 of set 12 | port blair
# Processing record 34 of set 12 | akyab
# Processing record 35 of set 12 | flin flon
# Processing record 36 of set 12 | mogadishu
# Processing record 37 of set 12 | grand gaube
# Processing record 38 of set 12 | agapovka
# Processing record 39 of set 12 | bogovarovo
# Processing record 40 of set 12 | neya
# Processing record 41 of set 12 | kibala
# Processing record 42 of set 12 | penzance
# Processing record 43 of set 12 | rock sound
# Processing record 44 of set 12 | goderich
# Processing record 45 of set 12 | santa rosalia
# Processing record 46 of set 12 | tiksi
# Processing record 47 of set 12 | sassandra
# Processing record 48 of set 12 | tallahassee
# Processing record 49 of set 12 | zurrieq
# Processing record 0 of set 13 | muros
# Processing record 1 of set 13 | tabialan
# City tabialan not found. Continuing...
# Processing record 2 of set 13 | mount gambier
# Processing record 3 of set 13 | kuvandyk
# Processing record 4 of set 13 | acajutla
# Processing record 5 of set 13 | ruteng
# Processing record 6 of set 13 | carahue
# Processing record 7 of set 13 | altamira
# Processing record 8 of set 13 | saint-louis
# Processing record 9 of set 13 | riaba
# City riaba not found. Continuing...
# Processing record 10 of set 13 | xining

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#store the required data
# create a data frame from cities, lat, and other retrieved data
weather_dict = {
            "city": city_name,
            "city_id": city_id,
            "lat": latitude,
            "max_temp": max_temp,
            "cloudiness": cloudiness,
            "country": country,
            "date": date,
            "humidity": humidity,
            "long": longitude,
            "wind_speed": wind_speed
    
        }
weather_data = pd.DataFrame(weather_dict)
weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 563 entries, 0 to 562
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   city        563 non-null    object
#  1   city_id     563 non-null    int64
#  2   lat         563 non-null    float64
#  3   max_temp    563 non-null    float64
#  4   cloudiness  563 non-null    int64
#  5   country     563 non-null    object
#  6   date        563 non-null    int64
#  7   humidity    563 non-null    int64
#  8   long        563 non-null    float64
#  9   wind_speed  563 non-null    float64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 44.1+ KB

# %%
#save the weather data to csv
weather_data.to_csv(output_data_file)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
remove_hum = weather_data.loc[weather_data.humidity < 101]
remove_hum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 563 entries, 0 to 562
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   city        563 non-null    object
#  1   city_id     563 non-null    int64
#  2   lat         563 non-null    float64
#  3   max_temp    563 non-null    float64
#  4   cloudiness  563 non-null    int64
#  5   country     563 non-null    object
#  6   date        563 non-null    int64
#  7   humidity    563 non-null    int64
#  8   long        563 non-null    float64
#  9   wind_speed  563 non-null    float64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 48.4+ KB

# %% [markdown]
# ## There are no cities that have over 100%  humidity

# %%
#  Get the indices of cities that have humidity over 100%.
over_hundred = []
over_hundred = weather_data.loc[weather_data.humidity > 100].index
over_hundred
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
clean_city_data = weather_data.drop(weather_data.index[over_hundred], inplace = False)
clean_city_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 563 entries, 0 to 562
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   city        563 non-null    object
#  1   city_id     563 non-null    int64
#  2   lat         563 non-null    float64
#  3   max_temp    563 non-null    float64
#  4   cloudiness  563 non-null    int64
#  5   country     563 non-null    object
#  6   date        563 non-null    int64
#  7   humidity    563 non-null    int64
#  8   long        563 non-null    float64
#  9   wind_speed  563 non-null    float64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 48.4+ KB

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
import datetime
#today = datetime.datetime.now()
#tday = str(today[:10])
#print(tday)

today = pd.to_datetime('today').date()
print(today)
# Out:
# 2020-12-05

# %%
clean_city_data.plot(kind='scatter', x='lat', y='max_temp',color = 'blue' )
title = f"City Latitude vs Max Temperature {today}"
plt.title(title)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid()
plt.savefig("output_data/lat_temp.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
clean_city_data.plot(kind='scatter', x='lat', y='humidity',color = 'blue' )
title = f"City Latitude vs Humidity {today}"
plt.title(title)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()
plt.savefig("output_data/lat_humidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
clean_city_data.plot(kind='scatter', x='lat', y='cloudiness',color = 'blue' )
title = f"City Latitude vs Cloudiness {today}"
plt.title(title)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.grid()
plt.savefig("output_data/lat_cloudiness.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
clean_city_data.plot(kind='scatter', x='lat', y='wind_speed',color = 'blue' )
title = f"City Latitude vs Wind Speed {today}"
plt.title(title)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.grid()
plt.savefig("output_data/lat_windspeed.png")

# %% [markdown]
# ## Linear Regression

# %%
northern = clean_city_data.loc[clean_city_data.lat >= 0]
northern.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 379 entries, 0 to 562
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   city        379 non-null    object
#  1   city_id     379 non-null    int64
#  2   lat         379 non-null    float64
#  3   max_temp    379 non-null    float64
#  4   cloudiness  379 non-null    int64
#  5   country     379 non-null    object
#  6   date        379 non-null    int64
#  7   humidity    379 non-null    int64
#  8   long        379 non-null    float64
#  9   wind_speed  379 non-null    float64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 32.6+ KB

# %%
southern = clean_city_data.loc[clean_city_data.lat < 0]
southern.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 184 entries, 1 to 560
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   city        184 non-null    object
#  1   city_id     184 non-null    int64
#  2   lat         184 non-null    float64
#  3   max_temp    184 non-null    float64
#  4   cloudiness  184 non-null    int64
#  5   country     184 non-null    object
#  6   date        184 non-null    int64
#  7   humidity    184 non-null    int64
#  8   long        184 non-null    float64
#  9   wind_speed  184 non-null    float64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 15.8+ KB

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northern.lat
y_values = northern.max_temp
plt.scatter(x_values,y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,62),fontsize=15,color="red")
title = f"Northern Hemisphere:City Latitude vs Max Temperature {today}"
plt.title(title)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid()
plt.savefig("output_data/northern_lat_temp.png")

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern.lat
y_values = southern.max_temp
plt.scatter(x_values,y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-28,70),fontsize=15,color="red")
title = f"Southern Hemisphere: City Latitude vs Max Temperature {today}"
plt.title(title)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (Fahrenheit)')
plt.grid()
plt.savefig("output_data/southern_lat_temp.png")

# %%
Analysis:

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern.lat
y_values = northern.humidity
plt.scatter(x_values,y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(50,60),fontsize=15,color="red")
title = f"Northern Hemisphere:City Latitude vs Humidity {today}"
plt.title(title)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()
plt.savefig("output_data/northern_lat_humidity.png")

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern.lat
y_values = southern.humidity
plt.scatter(x_values,y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20,60),fontsize=15,color="red")
title = f"Southern Hemisphere: City Latitude vs Humidity (%) {today}"
plt.title(title)
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.grid()
plt.savefig("output_data/southern_lat_humid.png")

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern.lat
y_values = northern.cloudiness
plt.scatter(x_values,y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,8),fontsize=15,color="red")
title = f"Northern Hemisphere:City Latitude vs Cloudiness {today}"
plt.title(title)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.grid()
plt.savefig("output_data/northern_lat_clouds.png")

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern.lat
y_values = southern.cloudiness
plt.scatter(x_values,y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20,60),fontsize=15,color="red")
title = f"Southern Hemisphere: City Latitude vs Cloudiness {today}"
plt.title(title)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.grid()
plt.savefig("output_data/southern_lat_cloudiness.png")

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern.lat
y_values = northern.wind_speed
plt.scatter(x_values,y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,10),fontsize=15,color="red")
title = f"Northern Hemisphere:City Latitude vs Wind Speed {today}"
plt.title(title)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.grid()
plt.savefig("output_data/northern_lat_wind.png")

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern.lat
y_values = southern.wind_speed
plt.scatter(x_values,y_values)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-20,15),fontsize=15,color="red")
title = f"Southern Hemisphere: City Latitude vs Wind Speed {today}"
plt.title(title)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.grid()
plt.savefig("output_data/southern_lat_wind.png")
